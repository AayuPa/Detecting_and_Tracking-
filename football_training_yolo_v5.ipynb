# %%
# !pip install ultralytics
# Out:
# Requirement already satisfied: ultralytics in /Users/aayushpawar/Desktop/football_tracker/.venv/lib/python3.14/site-packages (8.4.104)
# Requirement already satisfied: filelock>=3.16.1 in /Users/aayushpawar/Desktop/football_tracker/.venv/lib/python3.14/site-packages (from ultralytics) (3.32.0)
# Requirement already satisfied: numpy>=1.23.0 in /Users/aayushpawar/Desktop/football_tracker/.venv/lib/python3.14/site-packages (from ultralytics) (2.5.1)
# Requirement already satisfied: matplotlib>=3.3.0 in /Users/aayushpawar/Desktop/football_tracker/.venv/lib/python3.14/site-packages (from ultralytics) (3.11.1)
# Requirement already satisfied: opencv-python!=4.13.0.90,>=4.6.0 in /Users/aayushpawar/Desktop/football_tracker/.venv/lib/python3.14/site-packages (from ultralytics) (5.0.0.93)
# Requirement already satisfied: pillow>=7.1.2 in /Users/aayushpawar/Desktop/football_tracker/.venv/lib/python3.14/site-packages (from ultralytics) (12.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /Users/aayushpawar/Desktop/football_tracker/.venv/lib/python3.14/site-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in /Users/aayushpawar/Desktop/football_tracker/.venv/lib/python3.14/site-packages (from ultralytics) (2.34.2)
# Requirement already satisfied: torch>=1.8.0 in /Users/aayushpawar/Desktop/football_tracker/.venv/lib/python3.14/site-packages (from ultralytics) (2.13.0)
# Requirement already satisfied: torchvision>=0.9.0 in /Users/aayushpawar/Desktop/football_tracker/.venv/lib/python3.14/site-packages (from ultralytics) (0.28.0)
# Requirement already satisfied: psutil>=5.8.0 in /Users/aayushpawar/Desktop/football_tracker/.venv/lib/python3.14/site-packages (from ultralytics) (7.2.2)
# Requirement already satisfied: polars>=0.20.0 in /Users/aayushpawar/Desktop/football_tracker/.venv/lib/python3.14/site-packages (from ultralytics) (1.43.0)
# Requirement already satisfied: nvidia-ml-py>=12.0.0 in /Users/aayushpawar/Desktop/football_tracker/.venv/lib/python3.14/site-packages (from ultralytics) (13.610.43)
# Requirement already satisfied: ultralytics-thop>=2.0.18 in /Users/aayushpawar/Desktop/football_tracker/.venv/lib/python3.14/site-packages (from ultralytics) (2.0.20)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/aayushpawar/Desktop/football_tracker/.venv/lib/python3.14/site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/aayushpawar/Desktop/football_tracker/.venv/lib/python3.14/site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.28.2 in /Users/aayushpawar/Desktop/football_tracker/.venv/lib/python3.14/site-packages (from matplotlib>=3.3.0->ultralytics) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/aayushpawar/Desktop/football_tracker/.venv/lib/python3.14/site-packages (from matplotlib>=3.3.0->ultralytics) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /Users/aayushpawar/Desktop/football_tracker/.venv/lib/python3.14/site-packages (from matplotlib>=3.3.0->ultralytics) (26.2)
# Requirement already satisfied: pyparsing>=3 in /Users/aayushpawar/Desktop/football_tracker/.venv/lib/python3.14/site-packages (from matplotlib>=3.3.0->ultralytics) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/aayushpawar/Desktop/football_tracker/.venv/lib/python3.14/site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: polars-runtime-32==1.43.0 in /Users/aayushpawar/Desktop/football_tracker/.venv/lib/python3.14/site-packages (from polars>=0.20.0->ultralytics) (1.43.0)
# Requirement already satisfied: six>=1.5 in /Users/aayushpawar/Desktop/football_tracker/.venv/lib/python3.14/site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/aayushpawar/Desktop/football_tracker/.venv/lib/python3.14/site-packages (from requests>=2.23.0->ultralytics) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /Users/aayushpawar/Desktop/football_tracker/.venv/lib/python3.14/site-packages (from requests>=2.23.0->ultralytics) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in /Users/aayushpawar/Desktop/football_tracker/.venv/lib/python3.14/site-packages (from requests>=2.23.0->ultralytics) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in /Users/aayushpawar/Desktop/football_tracker/.venv/lib/python3.14/site-packages (from requests>=2.23.0->ultralytics) (2026.7.22)
# Requirement already satisfied: typing-extensions>=4.10.0 in /Users/aayushpawar/Desktop/football_tracker/.venv/lib/python3.14/site-packages (from torch>=1.8.0->ultralytics) (4.16.0)
# Requirement already satisfied: setuptools>=77.0.3 in /Users/aayushpawar/Desktop/football_tracker/.venv/lib/python3.14/site-packages (from torch>=1.8.0->ultralytics) (83.0.0)
# Requirement already satisfied: sympy>=1.13.3 in /Users/aayushpawar/Desktop/football_tracker/.venv/lib/python3.14/site-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /Users/aayushpawar/Desktop/football_tracker/.venv/lib/python3.14/site-packages (from torch>=1.8.0->ultralytics) (3.6.1)
# Requirement already satisfied: jinja2 in /Users/aayushpawar/Desktop/football_tracker/.venv/lib/python3.14/site-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /Users/aayushpawar/Desktop/football_tracker/.venv/lib/python3.14/site-packages (from torch>=1.8.0->ultralytics) (2026.6.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/aayushpawar/Desktop/football_tracker/.venv/lib/python3.14/site-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/aayushpawar/Desktop/football_tracker/.venv/lib/python3.14/site-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.3)

# %%
# !pip install roboflow
# Out:
# Collecting roboflow
#   Downloading roboflow-1.4.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: certifi in /Users/aayushpawar/Desktop/football_tracker/.venv/lib/python3.14/site-packages (from roboflow) (2026.7.22)
# Requirement already satisfied: idna>=3.7 in /Users/aayushpawar/Desktop/football_tracker/.venv/lib/python3.14/site-packages (from roboflow) (3.18)
# Requirement already satisfied: cycler in /Users/aayushpawar/Desktop/football_tracker/.venv/lib/python3.14/site-packages (from roboflow) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/aayushpawar/Desktop/football_tracker/.venv/lib/python3.14/site-packages (from roboflow) (1.5.0)
# Requirement already satisfied: matplotlib in /Users/aayushpawar/Desktop/football_tracker/.venv/lib/python3.14/site-packages (from roboflow) (3.11.1)
# Collecting numpy<2.4,>=1.18.5 (from roboflow)
#   Downloading numpy-2.3.5-cp314-cp314-macosx_14_0_arm64.whl.metadata (62 kB)
# Collecting opencv-python-headless==4.10.0.84 (from roboflow)
#   Downloading opencv_python_headless-4.10.0.84-cp37-abi3-macosx_11_0_arm64.whl.metadata (20 kB)
# Requirement already satisfied: Pillow>=7.1.2 in /Users/aayushpawar/Desktop/football_tracker/.venv/lib/python3.14/site-packages (from roboflow) (12.3.0)
# Collecting pi-heif<2 (from roboflow)
#   Downloading pi_heif-1.4.0-cp314-cp314-macosx_11_0_arm64.whl.metadata (6.3 kB)
# Collecting pillow-avif-plugin<2 (from roboflow)
#   Downloading pillow_avif_plugin-1.6.0-cp314-cp314-macosx_11_0_arm64.whl.metadata (2.2 kB)
# Requirement already satisfied: python-dateutil in /Users/aayushpawar/Desktop/football_tracker/.venv/lib/python3.14/site-packages (from roboflow) (2.9.0.post0)
# Collecting python-dotenv (from roboflow)
#   Using cached python_dotenv-1.2.2-py3-none-any.whl.metadata (27 kB)
# Requirement already satisfied: requests in /Users/aayushpawar/Desktop/football_tracker/.venv/lib/python3.14/site-packages (from roboflow) (2.34.2)
# Requirement already satisfied: six in /Users/aayushpawar/Desktop/football_tracker/.venv/lib/python3.14/site-packages (from roboflow) (1.17.0)
# Requirement already satisfied: urllib3>=1.26.6 in /Users/aayushpawar/Desktop/football_tracker/.venv/lib/python3.14/site-packages (from roboflow) (2.7.0)
# Requirement already satisfied: tqdm>=4.41.0 in /Users/aayushpawar/Desktop/football_tracker/.venv/lib/python3.14/site-packages (from roboflow) (4.69.0)
# Requirement already satisfied: PyYAML>=5.3.1 in /Users/aayushpawar/Desktop/football_tracker/.venv/lib/python3.14/site-packages (from roboflow) (6.0.3)
# Collecting requests_toolbelt (from roboflow)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Collecting filetype (from roboflow)
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting typer<0.26,>=0.12.0 (from roboflow)
#   Downloading typer-0.25.1-py3-none-any.whl.metadata (15 kB)
# Collecting click>=8.0 (from roboflow)
#   Downloading click-8.4.2-py3-none-any.whl.metadata (2.6 kB)
# Collecting shellingham>=1.3.0 (from typer<0.26,>=0.12.0->roboflow)
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting rich>=13.8.0 (from typer<0.26,>=0.12.0->roboflow)
#   Using cached rich-15.0.0-py3-none-any.whl.metadata (18 kB)
# Collecting annotated-doc>=0.0.2 (from typer<0.26,>=0.12.0->roboflow)
#   Using cached annotated_doc-0.0.4-py3-none-any.whl.metadata (6.6 kB)
# Collecting markdown-it-py>=2.2.0 (from rich>=13.8.0->typer<0.26,>=0.12.0->roboflow)
#   Using cached markdown_it_py-4.2.0-py3-none-any.whl.metadata (7.4 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/aayushpawar/Desktop/football_tracker/.venv/lib/python3.14/site-packages (from rich>=13.8.0->typer<0.26,>=0.12.0->roboflow) (2.20.0)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=13.8.0->typer<0.26,>=0.12.0->roboflow)
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/aayushpawar/Desktop/football_tracker/.venv/lib/python3.14/site-packages (from matplotlib->roboflow) (1.3.3)
# Requirement already satisfied: fonttools>=4.28.2 in /Users/aayushpawar/Desktop/football_tracker/.venv/lib/python3.14/site-packages (from matplotlib->roboflow) (4.63.0)
# Requirement already satisfied: packaging>=20.0 in /Users/aayushpawar/Desktop/football_tracker/.venv/lib/python3.14/site-packages (from matplotlib->roboflow) (26.2)
# Requirement already satisfied: pyparsing>=3 in /Users/aayushpawar/Desktop/football_tracker/.venv/lib/python3.14/site-packages (from matplotlib->roboflow) (3.3.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/aayushpawar/Desktop/football_tracker/.venv/lib/python3.14/site-packages (from requests->roboflow) (3.4.9)
# Downloading roboflow-1.4.0-py3-none-any.whl (285 kB)
# Downloading opencv_python_headless-4.10.0.84-cp37-abi3-macosx_11_0_arm64.whl (54.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.8/54.8 MB 4.1 MB/s  0:00:13m0:00:0100:01
# Downloading numpy-2.3.5-cp314-cp314-macosx_14_0_arm64.whl (5.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 6.8 MB/s  0:00:00 eta 0:00:01
# Downloading pi_heif-1.4.0-cp314-cp314-macosx_11_0_arm64.whl (959 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 959.7/959.7 kB 6.3 MB/s  0:00:00
# Downloading pillow_avif_plugin-1.6.0-cp314-cp314-macosx_11_0_arm64.whl (3.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 5.8 MB/s  0:00:00 eta 0:00:01
# Downloading typer-0.25.1-py3-none-any.whl (58 kB)
# Using cached annotated_doc-0.0.4-py3-none-any.whl (5.3 kB)
# Downloading click-8.4.2-py3-none-any.whl (119 kB)
# Using cached rich-15.0.0-py3-none-any.whl (310 kB)
# Using cached markdown_it_py-4.2.0-py3-none-any.whl (91 kB)
# Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Using cached python_dotenv-1.2.2-py3-none-any.whl (22 kB)
# Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Installing collected packages: pillow-avif-plugin, filetype, shellingham, python-dotenv, pi-heif, numpy, mdurl, click, annotated-doc, requests_toolbelt, opencv-python-headless, markdown-it-py, rich, typer, roboflow
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.5.1
#     Uninstalling numpy-2.5.1:
#       Successfully uninstalled numpy-2.5.1
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15/15 [roboflow]/15 [roboflow]thon-headless]
# Successfully installed annotated-doc-0.0.4 click-8.4.2 filetype-1.2.0 markdown-it-py-4.2.0 mdurl-0.1.2 numpy-2.3.5 opencv-python-headless-4.10.0.84 pi-heif-1.4.0 pillow-avif-plugin-1.6.0 python-dotenv-1.2.2 requests_toolbelt-1.0.0 rich-15.0.0 roboflow-1.4.0 shellingham-1.5.4 typer-0.25.1

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="eWxg0oC0dSZb9sbqfQ9r")
project = rf.workspace("roboflow-jvuqo").project("football-players-detection-3zvbc")
version = project.version(19)
dataset = version.download("yolov5")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in football-players-detection-19 to yolov5pytorch:: 100%|██████████| 23025/23025 [00:03<00:00, 5907.57it/s]
# Extracting Dataset Version Zip to football-players-detection-19 in yolov5pytorch:: 100%|██████████| 756/756 [00:00<00:00, 10518.39it/s]

# %%
dataset.location
# Out:
# '/Users/aayushpawar/Desktop/football_tracker/Ball_Tracking_by_Me/Training/football-players-detection-1'

# %%
import shutil
shutil.move('Football-players-detection-1/train','Football-players-detection-1/Football-players-detection-1/train')
shutil.move('Football-players-detection-1/test','Football-players-detection-1/Football-players-detection-1/test')
shutil.move('Football-players-detection-1/valid','Football-players-detection-1/Football-players-detection-1/valid')
# Out:
# 'Football-players-detection-1/Football-players-detection-1/valid'

# %% [markdown]
# # Training

# %%
# !yolo task=detect mode=train model=yolov5x.pt data={dataset.location}/data.yaml epochs=100 imgsz=640
# Out:
# PRO TIP 💡 Replace 'model=yolov5x.pt' with new 'model=yolov5xu.pt'.
# YOLOv5 'u' models are trained with https://github.com/ultralytics/ultralytics and feature improved performance vs standard YOLOv5 models trained with https://github.com/ultralytics/yolov5.
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov5xu.pt to 'yolov5xu.pt': 100% ━━━━━━━━━━━━ 186.1MB 5.5MB/s 34.0s33.9s<0.1ss
# Ultralytics 8.4.104 🚀 Python-3.14.3 torch-2.13.0 CPU (Apple M4)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, cls_remap=True, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/Users/aayushpawar/Desktop/football_tracker/Ball_Tracking_by_Me/Training/Football-players-3/data.yaml, degrees=0.0, deterministic=True, device=, dfl=1.5, dgrad=0.5, dis=6.0, distill_model=None, dlam=1.0, dlog=1.0, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=100, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov5x.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=train, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, quantize=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/Users/aayushpawar/Desktop/football_tracker/Ball_Tracking_by_Me/Training/runs/detect/train, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=tracktrack.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=4
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      8800  ultralytics.nn.modules.conv.Conv             [3, 80, 6, 2, 2]
#   1                  -1  1    115520  ultralytics.nn.modules.conv.Conv             [80, 160, 3, 2]
#   2                  -1  4    309120  ultralytics.nn.modules.block.C3              [160, 160, 4]
#   3                  -1  1    461440  ultralytics.nn.modules.conv.Conv             [160, 320, 3, 2]
#   4                  -1  8   2259200  ultralytics.nn.modules.block.C3              [320, 320, 8]
#   5                  -1  1   1844480  ultralytics.nn.modules.conv.Conv             [320, 640, 3, 2]
#   6                  -1 12  13125120  ultralytics.nn.modules.block.C3              [640, 640, 12]
#   7                  -1  1   7375360  ultralytics.nn.modules.conv.Conv             [640, 1280, 3, 2]
#   8                  -1  4  19676160  ultralytics.nn.modules.block.C3              [1280, 1280, 4]
#   9                  -1  1   4099840  ultralytics.nn.modules.block.SPPF            [1280, 1280, 5]
#  10                  -1  1    820480  ultralytics.nn.modules.conv.Conv             [1280, 640, 1, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  4   5332480  ultralytics.nn.modules.block.C3              [1280, 640, 4, False]
#  14                  -1  1    205440  ultralytics.nn.modules.conv.Conv             [640, 320, 1, 1]
#  15                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  16             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  17                  -1  4   1335040  ultralytics.nn.modules.block.C3              [640, 320, 4, False]
#  18                  -1  1    922240  ultralytics.nn.modules.conv.Conv             [320, 320, 3, 2]
#  19            [-1, 14]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  20                  -1  4   4922880  ultralytics.nn.modules.block.C3              [640, 640, 4, False]
#  21                  -1  1   3687680  ultralytics.nn.modules.conv.Conv             [640, 640, 3, 2]
#  22            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  23                  -1  4  19676160  ultralytics.nn.modules.block.C3              [1280, 1280, 4, False]
#  24        [17, 20, 23]  1  11025820  ultralytics.nn.modules.head.Detect           [4, 16, None, [320, 640, 1280]]
# YOLOv5x summary: 286 layers, 97,203,260 parameters, 97,203,244 gradients, 246.9 GFLOPs
#
# Transferred 817/823 items from pretrained weights
# Freezing layer 'model.24.dfl.conv.weight'
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 292.2±55.2 MB/s, size: 58.6 KB)
# train: Scanning /Users/aayushpawar/Desktop/football_tracker/Ball_Tracking_by_Me/Training/Football-players-3/Football-players-3/train/labels... 1070 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1070/1070 7.1Kit/s 0.2s2s
# train: New cache created: /Users/aayushpawar/Desktop/football_tracker/Ball_Tracking_by_Me/Training/Football-players-3/Football-players-3/train/labels.cache
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 327.3±55.5 MB/s, size: 58.1 KB)
# val: Scanning /Users/aayushpawar/Desktop/football_tracker/Ball_Tracking_by_Me/Training/Football-players-3/Football-players-3/valid/labels... 38 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 38/38 4.0Kit/s 0.0s
# val: New cache created: /Users/aayushpawar/Desktop/football_tracker/Ball_Tracking_by_Me/Training/Football-players-3/Football-players-3/valid/labels.cache
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.00125, momentum=0.9) with parameter groups 135 weight(decay=0.0), 142 weight(decay=0.0005), 141 bias(decay=0.0)
# Plotting labels to /Users/aayushpawar/Desktop/football_tracker/Ball_Tracking_by_Me/Training/runs/detect/train/labels.jpg...
# Image sizes 640 train, 640 val
# Using 0 dataloader workers
# Logging results to /Users/aayushpawar/Desktop/football_tracker/Ball_Tracking_by_Me/Training/runs/detect/train
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100         0G      1.473      1.395     0.8425        638        640: 50% ━━━━━━────── 34/67 67.8s/it 39:02<37:1817
# KeyboardInterrupt
